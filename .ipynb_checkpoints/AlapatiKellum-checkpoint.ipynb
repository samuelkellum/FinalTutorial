# %% [markdown]
# # Milestone 1
# ### Ajit Alapati and Samuel Kellum
#
#     For our collaboration plan, we decided to meet up in person to discuss what data about New Orleans we wanted to discuss. We set up a GitHub repository at first where we have been putting our data sources. We did face some initial challenges setting up the GitHub page because neither of us has ever created a GitHub page. Additionally, we had some small issues initializing the repository with the GitHub page because of GitHub’s new authentication features. In August, GitHub required that we use personal authentication tokens instead of account passwords when using its version control on the command line. Our planned technologies, as of now, are Docker, the Jupyter Notebook, Python, and all of the libraries it provides. We have not yet discussed in detail the libraries that we will use, but we will definitely be using Pandas, Numpy, and Matplotlib. We have each other’s phone numbers to contact each other about the project, and will most likely meet throughout the semester one or two times per week in person to work on the project. Both of us were interested in data about crime in New Orleans in addition to how the city has recovered from Hurricane Katrina.
#     We wanted to look into policing violence and where these incidents were happening in the city. These sorts of data sets open up many possible questions and avenues that we can go down. For example, we were discussing combining datasets to determine who and where these violent interactions were happening. Were they happening disproportionately in poor areas? Were they happening disproportionately towards African Americans?
#     Additionally, we are interested in exploring how different parts of the city have recovered from Hurricane Katrina. For example, even 15 years later, we know that New Orleans has still not fully recovered in population from before the storm. One dataset we found has information on the status of various houses that have been destroyed by the hurricane. It makes sense that the most essential functions of the city would be repaired first, but poor people who were displaced from New Orleans likely did not have as strong of an alternative outside of their homes and needed their houses repaired quickly. Did it take longer to rebuild houses in poor areas? Are some of those houses still destroyed? Are there significantly more vacant houses in poor areas that were destroyed by the hurricane?

# %%
# Load Numpy
import numpy as np
# Load MatPlotLib
import matplotlib
import matplotlib.pyplot as plt
# Load Pandas
import pandas as pd

# %%
police_complaint_df = pd.read_csv('./Data/NOPD_Misconduct_Complaints.csv')
police_complaint_df.head()
# Out:
#       Incident Type Complaint Tracking Number Date Complaint Occurred Date Complaint Received by NOPD (PIB) Date Complaint Investigation Complete Complaint classification Investigation status Disposition          Bureau of Complainant Division of Complainant Unit of Complainant Unit Additional Details of Complainant Working Status of Complainant Shift of Complainant         Rule Violation                                Paragraph Violation  Unique Officer Allegation ID Officer Race Ethnicity Officer Gender Officer Age  Officer years of service Complainant Gender Complainant Ethnicity  Complainant Age
# 0  Public Initiated               2016-0001-P              2016-01-01                            2016-01-01                            2016-07-21                     DI-1            Completed   Unfounded                            NaN            8th District                 NaN                                    NaN                           NaN                  NaN   RULE 3: PROF CONDUCT                     PARAGRAPH 01 - Professionalism                       30664.0                    NaN            NaN         NaN                       NaN               Male                 Black              NaN
# 1  Public Initiated               2016-0002-P              2016-01-02                            2016-01-01                            2016-08-03                     DI-1            Completed  Exonerated  FOB - Field Operations Bureau            7th District         Night Watch                                 Patrol               Regular Working     Between 11pm-7am   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                       30667.0                  Black           Male          60                       NaN             Female                 White              NaN
# 2  Public Initiated               2016-0002-P              2016-01-02                            2016-01-01                            2016-08-03                     DI-1            Completed  Exonerated  FOB - Field Operations Bureau            7th District         Night Watch                                 Patrol               Regular Working     Between 11pm-7am   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                       30669.0                  Black           Male          44                       NaN             Female                 White              NaN
# 3  Public Initiated               2016-0009-P              2016-01-04                            2016-01-04                            2017-03-20                     DI-1            Completed   Unfounded  FOB - Field Operations Bureau            8th District        8th District                                 Patrol               Regular Working     Between 3pm-11pm  RULE 2: MORAL CONDUCT                    PARAGRAPH 01 - ADHERENCE TO LAW                       30671.0                  White           Male         NaN                       NaN                NaN                   NaN              NaN
# 4  Public Initiated               2016-0006-P              2016-12-30                            2016-01-04                            2016-07-25                     DI-1            Completed  Exonerated  FOB - Field Operations Bureau           Command Staff               Admin                                    NaN                           NaN                  NaN   RULE 4: PERF OF DUTY  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE...                       30674.0                  Black           Male          54                       NaN             Female                 Black             50.0

# %%
#Tidying data by dropping columns we don't plan on using
del police_complaint_df['Incident Type']
del police_complaint_df['Complaint Tracking Number']
del police_complaint_df['Date Complaint Received by NOPD (PIB)']
del police_complaint_df['Date Complaint Occurred']
del police_complaint_df['Date Complaint Investigation Complete']
del police_complaint_df['Bureau of Complainant']
del police_complaint_df['Shift of Complainant']
del police_complaint_df['Unique Officer Allegation ID']

# %%
police_complaint_df.head()
# Out:
#   Complaint classification Investigation status Disposition Division of Complainant Unit of Complainant Unit Additional Details of Complainant Working Status of Complainant         Rule Violation                                Paragraph Violation Officer Race Ethnicity Officer Gender Officer Age  Officer years of service Complainant Gender Complainant Ethnicity  Complainant Age
# 0                     DI-1            Completed   Unfounded            8th District                 NaN                                    NaN                           NaN   RULE 3: PROF CONDUCT                     PARAGRAPH 01 - Professionalism                    NaN            NaN         NaN                       NaN               Male                 Black              NaN
# 1                     DI-1            Completed  Exonerated            7th District         Night Watch                                 Patrol               Regular Working   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                  Black           Male          60                       NaN             Female                 White              NaN
# 2                     DI-1            Completed  Exonerated            7th District         Night Watch                                 Patrol               Regular Working   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                  Black           Male          44                       NaN             Female                 White              NaN
# 3                     DI-1            Completed   Unfounded            8th District        8th District                                 Patrol               Regular Working  RULE 2: MORAL CONDUCT                    PARAGRAPH 01 - ADHERENCE TO LAW                  White           Male         NaN                       NaN                NaN                   NaN              NaN
# 4                     DI-1            Completed  Exonerated           Command Staff               Admin                                    NaN                           NaN   RULE 4: PERF OF DUTY  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE...                  Black           Male          54                       NaN             Female                 Black             50.0

# %%
#Since this data frame does not contain useful information about Officer years of service, we will drop this column
police_complaint_df['Officer years of service'].describe()
# Out:
# count     4.000000
# mean     32.750000
# std       6.291529
# min      28.000000
# 25%      29.500000
# 50%      30.500000
# 75%      33.750000
# max      42.000000
# Name: Officer years of service, dtype: float64

# %%
del police_complaint_df['Officer years of service']

# %%
police_complaint_df
# Out:
#      Complaint classification Investigation status Disposition Division of Complainant Unit of Complainant Unit Additional Details of Complainant Working Status of Complainant         Rule Violation                                Paragraph Violation Officer Race Ethnicity Officer Gender Officer Age Complainant Gender Complainant Ethnicity  Complainant Age
# 0                        DI-1            Completed   Unfounded            8th District                 NaN                                    NaN                           NaN   RULE 3: PROF CONDUCT                     PARAGRAPH 01 - Professionalism                    NaN            NaN         NaN               Male                 Black              NaN
# 1                        DI-1            Completed  Exonerated            7th District         Night Watch                                 Patrol               Regular Working   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                  Black           Male          60             Female                 White              NaN
# 2                        DI-1            Completed  Exonerated            7th District         Night Watch                                 Patrol               Regular Working   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                  Black           Male          44             Female                 White              NaN
# 3                        DI-1            Completed   Unfounded            8th District        8th District                                 Patrol               Regular Working  RULE 2: MORAL CONDUCT                    PARAGRAPH 01 - ADHERENCE TO LAW                  White           Male         NaN                NaN                   NaN              NaN
# 4                        DI-1            Completed  Exonerated           Command Staff               Admin                                    NaN                           NaN   RULE 4: PERF OF DUTY  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE...                  Black           Male          54             Female                 Black             50.0
# ...                       ...                  ...         ...                     ...                 ...                                    ...                           ...                    ...                                                ...                    ...            ...         ...                ...                   ...              ...
# 5853                      NaN              Initial     Pending            5th District               Staff                                    NaN                           NaN   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                  Black           Male         NaN                NaN                   NaN              NaN
# 5854                      NaN              Initial     Pending            5th District               Staff                                    NaN                           NaN   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                  Black           Male         NaN                NaN                   NaN              NaN
# 5855                     DI-1              Initial     Pending            3rd District        3rd District                                 Patrol               Regular Working   RULE 3: PROF CONDUCT            PARAGRAPH 13 - Social Networking...etc.                  White         Female          24                NaN                   NaN              NaN
# 5856                     NFIM              Initial     Pending                     NaN                 NaN                                    NaN                           NaN   RULE 4: PERF OF DUTY                     PARAGRAPH 04 - NEGLECT OF DUTY                    NaN            NaN         NaN               Male                 Black             29.0
# 5857                     DI-1              Initial     Pending            1st District          Task Force                                    NaN        Unknown Working Status  RULE 6: OFFICIAL INFO         PARAGRAPH 02 - FALSE OR INACCURATE REPORTS                  Black           Male          34             Female                 White             30.0
#
# [5858 rows x 15 columns]
