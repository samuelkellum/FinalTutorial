# %% [markdown]
# # Milestone 1
# ### Ajit Alapati and Samuel Kellum
#
#     For our collaboration plan, we decided to meet up in person to discuss what data about New Orleans we wanted to discuss. We set up a GitHub repository at first where we have been putting our data sources. We did face some initial challenges setting up the GitHub page because neither of us has ever created a GitHub page. Additionally, we had some small issues initializing the repository with the GitHub page because of GitHub’s new authentication features. In August, GitHub required that we use personal authentication tokens instead of account passwords when using its version control on the command line. Our planned technologies, as of now, are Docker, the Jupyter Notebook, Python, and all of the libraries it provides. We have not yet discussed in detail the libraries that we will use, but we will definitely be using Pandas, Numpy, and Matplotlib. We have each other’s phone numbers to contact each other about the project, and will most likely meet throughout the semester one or two times per week in person to work on the project. Both of us were interested in data about crime in New Orleans in addition to how the city has recovered from Hurricane Katrina.
#     We wanted to look into policing violence and where these incidents were happening in the city. These sorts of data sets open up many possible questions and avenues that we can go down. For example, we were discussing combining datasets to determine who and where these violent interactions were happening. Were they happening disproportionately in poor areas? Were they happening disproportionately towards African Americans?
#     Additionally, we are interested in exploring how different parts of the city have recovered from Hurricane Katrina. For example, even 15 years later, we know that New Orleans has still not fully recovered in population from before the storm. One dataset we found has information on the status of various houses that have been destroyed by the hurricane. It makes sense that the most essential functions of the city would be repaired first, but poor people who were displaced from New Orleans likely did not have as strong of an alternative outside of their homes and needed their houses repaired quickly. Did it take longer to rebuild houses in poor areas? Are some of those houses still destroyed? Are there significantly more vacant houses in poor areas that were destroyed by the hurricane?

# %%
# Load Numpy
import numpy as np
# Load MatPlotLib
import matplotlib
import matplotlib.pyplot as plt
# Load Pandas
import pandas as pd

# %%
police_df = pd.read_csv('./Data/NOPD_Use_of_Force_Incidents.csv')

# %%
# Out:
#      PIB File Number Date Occurred             Originating Bureau Division level      Division    Unit   Working Status             Shift Investigation status    Disposition      Service Type Light Condition Weather Condition                            Use of Force Type Use of Force Level Subject Influencing Factors Use of Force Effective Officer Race/Ethnicity      Officer Gender Officer Age Officer Years of Service    Distance Between Subject Gender Subject Ethnicity Subject Age Subject Build   Subject Height Subject Injured Subject Hospitalized Subject Arrested Subject Arrest Charges      Use of Force Reason Officer Injured
# 2742    FTN2020-0288    09/29/2020  FOB - Field Operations Bureau   5th District     B Platoon  Patrol  Regular Working  Between 3pm-11pm            Completed  UOF Justified  Call for Service            Good  Clear Conditions                               CEW Deployment                 L2           Mentally unstable                    Yes                  White                Male          24                        1    4 feet to 6 feet           Male             Black          59        Medium   5'7'' to 5'9''             Yes                  Yes               No                    NaN         Weapon Exhibited              No
# 2743    FTN2020-0289    09/29/2020  FOB - Field Operations Bureau   7th District     B Platoon  Patrol  Regular Working  Between 3pm-11pm            Completed  UOF Justified  Call for Service            Good  Clear Conditions  Takedown (no injury) | Takedown (no injury)            L1 | L1               None detected              Yes | Yes       White | Hispanic         Male | Male     31 | 30                    7 | 3    0 feet to 1 feet           Male             Black          20        Medium   5'7'' to 5'9''             Yes                   No              Yes                    NaN  Resisting Lawful Arrest        Yes | No
# 2744    FTN2020-0290    09/30/2020  FOB - Field Operations Bureau   3rd District     C Platoon  Patrol  Regular Working  Between 11pm-7am            Completed  UOF Justified         Arresting            Poor  Clear Conditions                          Firearm (Exhibited)                 L1               None detected                    Yes                  White                Male          51                       18    1 feet to 3 feet           Male             Black          35        Medium  5'10'' to 6'0''              No                   No              Yes                    NaN     Tactical Deployments              No
# 2745    FTN2020-0291    10/01/2020  FOB - Field Operations Bureau   6th District     B Platoon  Patrol  Regular Working  Between 3pm-11pm            Completed  UOF Justified         Arresting            Poor  Clear Conditions                          Firearm (Exhibited)                 L1               None detected                    Yes                  Black                Male         NaN                        2  11 feet to 14 feet           Male             Black          36         Large   6'1'' to 6'3''              No                   No              Yes                    NaN   Flight from an Officer              No
# 2746    FTN2020-0293    10/03/2020  FOB - Field Operations Bureau   1st District  1st District  Patrol  Regular Working  Between 3pm-11pm            Completed  UOF Justified         Arresting            Good  Clear Conditions          Hands | Firearm (Exhibited) | Hands       L1 | L1 | L1           Mentally unstable         Yes | No | Yes       White | White |   Male | Male | Male  33 | 29 |                 6 | 3 | 2    1 feet to 3 feet         Female             Black          26         Large   5'4'' to 5'6''              No                  Yes              Yes                    NaN  Resisting Lawful Arrest    No | No | No
